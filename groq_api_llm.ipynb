# %% [markdown]
# <a href="https://colab.research.google.com/github/aagamaar/Learning_Gen_AI/blob/main/groq_api_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 4.6 MB/s eta 0:00:00

# %%
import os

# %%
os.environ["GROQ_API_KEY"] = "your_groq_api_key"

# %%
from groq import Groq

client = Groq()

chat_completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "What is Deep Learning?"}
    ]
)

print(chat_completion.choices[0].message.content)
# Out:
# Deep learning is a subset of machine learning that utilizes artificial neural networks (ANNs) with multiple layers, which are inspired by the structure and function of the human brain. These networks are capable of automatically learning and improving from experience, without being explicitly programmed.
#
# The core idea of deep learning is to feed an input to the network, which then processes and transforms the data through a series of hierarchical layers, each composed of interconnected nodes or "neurons." These layers gradually extract and represent increasingly abstract and complex features of the input data.
#
# The key characteristics of deep learning are:
#
# 1. **Multi-layered architecture**: Deep learning models consist of multiple layers, each of which processes the input data in a different way, allowing the model to learn complex representations of the data.
# 2. **Neural networks**: Deep learning models are based on artificial neural networks, which are inspired by the structure and function of the human brain.
# 3. **Automatic learning**: Deep learning models can automatically learn and improve from experience, without being explicitly programmed.
# 4. **Large datasets**: Deep learning models typically require large datasets to learn from, as the complexity of the model requires a significant amount of data to train and validate.
# 5. **Computationally intensive**: Deep learning models are computationally intensive, requiring powerful hardware and software to execute.
#
# Some of the key applications of deep learning include:
#
# 1. **Computer vision**: Image and video recognition, object detection, segmentation, and tracking.
# 2. **Natural language processing**: Text classification, sentiment analysis, language translation, and language understanding.
# 3. **Speech recognition**: Speech-to-text systems, voice recognition, and speech-to-speech systems.
# 4. **Robotics**: Control and navigation of robots, manipulation of objects, and autonomous driving.
# 5. **Game playing**: Playing complex games, such as Go, Poker, and Chess.
#
# Some of the popular deep learning techniques include:
#
# 1. **Convolutional Neural Networks (CNNs)**: Used for image and video processing.
# 2. **Recurrent Neural Networks (RNNs)**: Used for sequential data, such as speech and text.
# 3. **Autoencoders**: Used for unsupervised learning and dimensionality reduction.
# 4. **Generative Adversarial Networks (GANs)**: Used for generating new data, such as images and text.
# 5. **Long Short-Term Memory (LSTM) networks**: Used for sequential data, such as speech and text.
#
# Overall, deep learning has become a crucial tool in various fields, including computer vision, natural language processing, speech recognition, and more, enabling the creation of intelligent systems that can perform tasks that would be difficult or impossible for humans to accomplish.

# %%
from groq import Groq

client = Groq()

chat_completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "What is Deep Learning?"},
        {"role": "assistant", "content": "Deep learning is a subfield of machine learning that involves the use of artificial neural networks (ANNs) to analyze and interpret data."},
        {"role": "user", "content": "Give some applications."}
    ]
)

print(chat_completion.choices[0].message.content)
# Out:
# Deep learning has numerous applications across various industries. Here are some examples:
#
# 1. **Image Recognition**: Google Photos uses deep learning to recognize and categorize images, such as identifying people, objects, and scenes.
# 2. **Natural Language Processing (NLP)**: Virtual assistants like Siri, Alexa, and Google Assistant use deep learning to understand and respond to voice commands.
# 3. **Self-Driving Cars**: Companies like Tesla and Waymo use deep learning to develop autonomous vehicles that can perceive and respond to their environment.
# 4. **Medical Diagnosis**: Deep learning is used in medical imaging to detect diseases such as cancer, tumors, and cardiovascular conditions.
# 5. **Speech Recognition**: Speech recognition systems, such as voice-to-text software, use deep learning to recognize spoken words and transcribe them into text.
# 6. **Recommendation Systems**: Online services like Netflix and Amazon use deep learning to recommend products and content to users based on their preferences.
# 7. **Security and Surveillance**: Deep learning-based systems can detect and classify security threats, such as facial recognition and intrusion detection.
# 8. **Robotics**: Deep learning is used in robotics to enable robots to learn and adapt to new situations, such as robotic hands that can grasp and manipulate objects.
# 9. **Chatbots and Virtual Assistants**: Chatbots and virtual assistants use deep learning to understand user inputs and respond with relevant and helpful information.
# 10. **Predictive Maintenance**: Deep learning can be used to predict equipment failures and schedule maintenance, reducing downtime and improving productivity.
#
# These are just a few examples of the many applications of deep learning. As the field continues to evolve, we can expect to see even more innovative uses of deep learning in various industries.
